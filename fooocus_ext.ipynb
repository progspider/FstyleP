# %%
# @markdown # Select profile of Fooocus and start/restart

Fooocus_Profile = "realistic" #@param ["default", "realistic", "anime"]
Fooocus_Theme = "dark" #@param ["dark", "light"]

# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
#run foocus
if Fooocus_Profile=='default':
  profile=""
if Fooocus_Profile=='realistic':
  profile="--preset realistic"
if Fooocus_Profile=='anime':
  profile="--preset anime"

if Fooocus_Theme=='dark':
  theme="--theme dark"
if Fooocus_Theme=='light':
  theme=""


# !python entry_with_update.py {profile} {theme} --share
# Out:
# Requirement already satisfied: pygit2==1.12.2 in /usr/local/lib/python3.10/dist-packages (1.12.2)
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.21)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--preset', 'realistic', '--theme', 'dark', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.865
# Loaded preset: /content/Fooocus/presets/realistic.json
# Installing Prompt_translate requirement -> deep-translator
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: NORMAL_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# 2024-02-19 16:52:26.895925: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-19 16:52:26.895989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-19 16:52:26.897978: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-19 16:52:28.954272: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Prompt translate module AlekPet -> Loaded
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://bc65fe6344330d4a58.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids'}
# Base model loaded: /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
# Request to load LoRAs [['SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors', 0.25], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for UNet [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 788 keys at weight 0.25.
# Loaded LoRA [/content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors] for CLIP [/content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors] with 264 keys at weight 0.25.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.14 seconds
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://bc65fe6344330d4a58.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 6556405706392848944
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] girls swam in the lake, our rubber dick, heavenly light, cute inspired colors, intricate, elegant, sharp focus, professional, cinematic, highly detailed, very fine detail, iconic, innocent, symmetry, altered, clear, aesthetic, extremely delicate, cool, epic, artistic, pure, color, illuminated, shining, great, full, perfect, focused, bright
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] girls swam in the lake, our rubber dick, intricate, elegant, highly detailed, wonderful dynamic, dramatic light, sharp focus, cinematic, fine composition, joyful, scenic, warm colors, inspired, noble, amazing, awesome, perfect, artistic, color crisp, epic, best, beautiful, creative, fabulous, illuminated, pretty, background, bright, lovely, majestic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] girls swam in the lake, our rubber dick, full detail, professional composition, emotional, shiny, vivid, beautiful, surreal, sharp focus, pretty, romantic, intricate, elegant, highly detailed, artistic, color spread, creative, ambient light, fancy, cinematic, background, magic, vibrant, focused, perfect, best, smart, sunny, precious, adorned
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] girls swam in the lake, our rubber dick, perfect full focus, cinematic, elegant, intricate, highly detailed, very inspired, innocent, composed, cute, creative, pure, dramatic light, attractive, beautiful, artistic, sharp, fine detail, complex, enhanced, amazing, colorful, illuminated, color, epic, coherent, symmetry, pretty background, ambient, radiant
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 7.51 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.21 seconds
# 100% 30/30 [00:26<00:00,  1.15it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 31.45 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.00 seconds
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 31.69 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.94 seconds
# 100% 30/30 [00:28<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 33.04 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.91 seconds
# 100% 30/30 [00:27<00:00,  1.11it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 32.80 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# Total time: 146.29 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 4707321733636213339
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 0.70 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.04 seconds
#  43% 13/30 [00:12<00:16,  1.01it/s]
# User stopped
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 16.77 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 3.0
# [Parameters] Seed = 8584815699308965461
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1152, 896)
# Preparation time: 0.64 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.98 seconds
# 100% 30/30 [00:29<00:00,  1.03it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 34.09 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.93 seconds
# 100% 30/30 [00:27<00:00,  1.09it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 32.45 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.07 seconds
# 100% 30/30 [00:27<00:00,  1.08it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 32.70 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.97 seconds
# 100% 30/30 [00:27<00:00,  1.07it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# Image generated with private log at: /content/Fooocus/outputs/2024-02-19/log.html
# Generating and saving time: 32.92 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.98 seconds
# Total time: 144.29 seconds
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 128, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 695, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2203, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 49, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://bc65fe6344330d4a58.gradio.live

# %%
# @markdown # For CivitAI ONLY

#download model

CivitAI_API_KEY = "" #@param {type:"string"}


# @markdown ##If necessary, change the link to the form
# @markdown ##Original link - https://civitai.com/api/download/models/329647?type=Model&format=SafeTensor
# @markdown ##Paste link - https://civitai.com/api/download/models/329647

Add_Model = False #@param {type:"boolean"}
if Add_Model == True :
  # %cd /content/Fooocus/models/checkpoints
  URL_Model = "" #@param {type:"string"}
  # !wget {URL_Model}'?token='{CivitAI_API_KEY} --content-disposition



#download lora
# %cd /content/Fooocus/models/loras
Add_Lora1 = False #@param {type:"boolean"}
if Add_Lora1 == True :
  URL_Lora1 = "" #@param {type:"string"}
  # !wget {URL_Lora1}'?token='{CivitAI_API_KEY} --content-disposition


Add_Lora2 = False #@param {type:"boolean"}
if Add_Lora2 == True :
  URL_Lora2 = "" #@param {type:"string"}
  # !wget {URL_Lora2}'?token='{CivitAI_API_KEY} --content-disposition

Add_Lora3 = False #@param {type:"boolean"}
if Add_Lora3 == True :
  URL_Lora3 = "" #@param {type:"string"}
  # !wget {URL_Lora3}'?token='{CivitAI_API_KEY} --content-disposition

Add_Lora4 = False #@param {type:"boolean"}
if Add_Lora4 == True :
  URL_Lora4 = "" #@param {type:"string"}
  # !wget {URL_Lora4}'?token='{CivitAI_API_KEY} --content-disposition
# Out:
# /content/Fooocus/models/checkpoints
# --2024-02-05 11:49:53--  https://civitai.com/api/download/models/157707?token=85787ad46c0ac8782754057a18dd757a
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1479508/nsfwSevenof9V3.WVMe.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22nsfwSevenof9V3_nsfwSevenof9V3.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T114953Z&X-Amz-SignedHeaders=host&X-Amz-Signature=faf08d80d9cfeaa009220f4f1508f2cec0b4c0fb8b1d5223d15855c2d3e92f53 [following]
# --2024-02-05 11:49:54--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1479508/nsfwSevenof9V3.WVMe.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22nsfwSevenof9V3_nsfwSevenof9V3.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T114953Z&X-Amz-SignedHeaders=host&X-Amz-Signature=faf08d80d9cfeaa009220f4f1508f2cec0b4c0fb8b1d5223d15855c2d3e92f53
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6938041020 (6.5G) [application/octet-stream]
# Saving to: ‘nsfwSevenof9V3_nsfwSevenof9V3.safetensors’
#
# nsfwSevenof9V3_nsfw 100%[===================>]   6.46G  37.3MB/s    in 3m 19s
#
# 2024-02-05 11:53:14 (33.3 MB/s) - ‘nsfwSevenof9V3_nsfwSevenof9V3.safetensors’ saved [6938041020/6938041020]
#
# Lora1
# /content/Fooocus/models/loras
# --2024-02-05 11:53:14--  https://civitai.com/api/download/models/142513?token=85787ad46c0ac8782754057a18dd757a
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/698588/model/chilloutnsfwfixV1.5pEE.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22chilloutNsfwFix_v1.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115315Z&X-Amz-SignedHeaders=host&X-Amz-Signature=990b5d5d54cd9b6820d6b0539d5ede35fbaef047249ef84b8733c09550f722ec [following]
# --2024-02-05 11:53:15--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/698588/model/chilloutnsfwfixV1.5pEE.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22chilloutNsfwFix_v1.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115315Z&X-Amz-SignedHeaders=host&X-Amz-Signature=990b5d5d54cd9b6820d6b0539d5ede35fbaef047249ef84b8733c09550f722ec
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 108612512 (104M) [application/octet-stream]
# Saving to: ‘chilloutNsfwFix_v1.safetensors’
#
# chilloutNsfwFix_v1. 100%[===================>] 103.58M  84.9MB/s    in 1.2s
#
# 2024-02-05 11:53:16 (84.9 MB/s) - ‘chilloutNsfwFix_v1.safetensors’ saved [108612512/108612512]
#
# Lora2
# --2024-02-05 11:53:16--  https://civitai.com/api/download/models/301328?token=85787ad46c0ac8782754057a18dd757a
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2938711/nsfwMIXEDITION000001.UUGf.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NSFW_MIX_EDITION-000001.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115317Z&X-Amz-SignedHeaders=host&X-Amz-Signature=44278ae875a463e07cedce6ba95079d6b20e4c1b6293bc2b838897a5937785f0 [following]
# --2024-02-05 11:53:17--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2938711/nsfwMIXEDITION000001.UUGf.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NSFW_MIX_EDITION-000001.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115317Z&X-Amz-SignedHeaders=host&X-Amz-Signature=44278ae875a463e07cedce6ba95079d6b20e4c1b6293bc2b838897a5937785f0
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228514212 (218M)
# Saving to: ‘NSFW_MIX_EDITION-000001.safetensors’
#
# NSFW_MIX_EDITION-00 100%[===================>] 217.93M  71.4MB/s    in 3.1s
#
# 2024-02-05 11:53:20 (71.4 MB/s) - ‘NSFW_MIX_EDITION-000001.safetensors’ saved [228514212/228514212]
#
# Lora3
# --2024-02-05 11:53:20--  https://civitai.com/api/download/models/326977?token=85787ad46c0ac8782754057a18dd757a
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2253457/latexTanktopPantsBy.oBdE.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Latex_TankTop_Pants_By_Stable_Yogi.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115321Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a6de540297f98aedfcd4e708f8cebed38a69161e79b4ef8c00ea358eb1dbd4f4 [following]
# --2024-02-05 11:53:21--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2253457/latexTanktopPantsBy.oBdE.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Latex_TankTop_Pants_By_Stable_Yogi.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115321Z&X-Amz-SignedHeaders=host&X-Amz-Signature=a6de540297f98aedfcd4e708f8cebed38a69161e79b4ef8c00ea358eb1dbd4f4
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18986528 (18M) [application/octet-stream]
# Saving to: ‘Latex_TankTop_Pants_By_Stable_Yogi.safetensors’
#
# Latex_TankTop_Pants 100%[===================>]  18.11M  62.9MB/s    in 0.3s
#
# 2024-02-05 11:53:22 (62.9 MB/s) - ‘Latex_TankTop_Pants_By_Stable_Yogi.safetensors’ saved [18986528/18986528]
#
# Lora4
# --2024-02-05 11:53:22--  https://civitai.com/api/download/models/298738?token=85787ad46c0ac8782754057a18dd757a
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2253457/latexSkeletonBonesDress.fxLH.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Latex_Skeleton_Bones_Dress_By_Stable_Yogi.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115323Z&X-Amz-SignedHeaders=host&X-Amz-Signature=2c349b8d57e797ae87c83e3614d8148c696e9ab062abbaa637f08190077b7c11 [following]
# --2024-02-05 11:53:23--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2253457/latexSkeletonBonesDress.fxLH.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22Latex_Skeleton_Bones_Dress_By_Stable_Yogi.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240205/us-east-1/s3/aws4_request&X-Amz-Date=20240205T115323Z&X-Amz-SignedHeaders=host&X-Amz-Signature=2c349b8d57e797ae87c83e3614d8148c696e9ab062abbaa637f08190077b7c11
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18986536 (18M) [application/octet-stream]
# Saving to: ‘Latex_Skeleton_Bones_Dress_By_Stable_Yogi.safetensors’
#
# Latex_Skeleton_Bone 100%[===================>]  18.11M  78.5MB/s    in 0.2s
#
# 2024-02-05 11:53:24 (78.5 MB/s) - ‘Latex_Skeleton_Bones_Dress_By_Stable_Yogi.safetensors’ saved [18986536/18986536]

# %%
# @markdown # Start for save 'outputs' to Google drive

from google.colab import drive
drive.mount('/content/drive')
try:
    with open("/content/Fooocus/config.txt", "r+") as text_file:
        texts = text_file.read()
        texts = texts.replace("/content/Fooocus/outputs", "/content/drive/MyDrive/outputs")
    with open("/content/Fooocus/config.txt", "w") as text_file:
        text_file.write(texts)
except FileNotFoundError as f:
    print("Could not find the file you are trying to read.")
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !mkdir /content/drive/MyDrive/outputs
# Out:
# Mounted at /content/drive
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/MyDrive/outputs’: File exists

# %%
# @markdown # Prompt Google.Translate
# %cd /content
# !wget https://github.com/AlekPet/Fooocus_Extensions_AlekPet/archive/refs/heads/main.zip
# !unzip -o /content/main.zip
# !cp -r /content/Fooocus_Extensions_AlekPet-main/patcher_webui.py /content/patcher_webui.py
# !cp -r /content/Fooocus_Extensions_AlekPet-main/prompt_translate/modules/module_translate.py /content/Fooocus/modules/module_translate.py
# !python /content/patcher_webui.py
# !rm -rf /content/Fooocus_Extensions_AlekPet-main
# !rm main.zip
# Out:
# /content
# --2024-02-19 16:51:57--  https://github.com/AlekPet/Fooocus_Extensions_AlekPet/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/AlekPet/Fooocus_Extensions_AlekPet/zip/refs/heads/main [following]
# --2024-02-19 16:51:57--  https://codeload.github.com/AlekPet/Fooocus_Extensions_AlekPet/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [ <=>                ]  91.18K  --.-KB/s    in 0.02s
#
# 2024-02-19 16:51:57 (4.83 MB/s) - ‘main.zip’ saved [93369]
#
# Archive:  /content/main.zip
# c6da84e1778240cea7c452f5b8dc680077a0c3c8
#    creating: Fooocus_Extensions_AlekPet-main/
#   inflating: Fooocus_Extensions_AlekPet-main/LICENSE
#   inflating: Fooocus_Extensions_AlekPet-main/README.md
#    creating: Fooocus_Extensions_AlekPet-main/assets/
#    creating: Fooocus_Extensions_AlekPet-main/assets/images/
#   inflating: Fooocus_Extensions_AlekPet-main/assets/images/image_prompt_translate.jpg
#   inflating: Fooocus_Extensions_AlekPet-main/patcher_webui.py
#    creating: Fooocus_Extensions_AlekPet-main/prompt_translate/
#   inflating: Fooocus_Extensions_AlekPet-main/prompt_translate/README.md
#    creating: Fooocus_Extensions_AlekPet-main/prompt_translate/modules/
#   inflating: Fooocus_Extensions_AlekPet-main/prompt_translate/modules/module_translate.py
#   inflating: Fooocus_Extensions_AlekPet-main/prompt_translate/webui.py
# === Script for patching file webui.py for Fooocus ===
# > Extension: 'Prompt Translate'
# > Author: AlekPet
# > Github: https://github.com/AlekPet/Fooocus_Extensions_AlekPet
# === ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ===
# Patches applied to file 6 of 6 [100.0%)]
# Patched successfully!
